# %%
import numpy  as np 
import matplotlib.pyplot as plt

# %%
array1 = np.array([[1,2,3],[4,5,6]])
array2 = np.random.rand(3,3)
array3 = np.zeros((4,4))

np.save('array1.npy',array1) #save the matrix in permanent files -np.save('nameoffile.npy',array_to_save)
np.save('array2.npy',array2)
np.save('array3.npy',array3)

# %%
loaded_array1 = np.load('array1.npy') #load preexisting array stored in file.- np.load('location of file')
print(loaded_array1)
# Out:
# [[1 2 3]
#  [4 5 6]]
